# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the data

# %%
store=pd.read_excel('D:\\PGP IN DATA SCIENCE with careerera\\Data sets\\Global_Superstore.xlsx')
store.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Sub-Category                               Product Name     Sales  \
# ...

# %%
pd.options.display.max_columns=30
store.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#              State        Country          Region        Market   Product ID  \
# ...

# %%
store.shape
# Out:
# (51290, 26)

# %% [markdown]
# ## Column information

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Row ID                   51290 non-null  int64
#  1   Order ID                 51290 non-null  object
#  2   Order Date               51290 non-null  datetime64[ns]
#  3   Ship Date                51290 non-null  datetime64[ns]
#  4   Ship Mode                51290 non-null  object
#  5   Customer ID              51290 non-null  object
#  6   Customer Name            51290 non-null  object
#  7   Segment                  51290 non-null  object
#  8   Postal Code              9994 non-null   float64
#  9   City                     51290 non-null  object
#  10  State                    51290 non-null  object
#  11  Country                  51290 non-null  object
#  12  Region                   51290 non-null  object
# ...

# %% [markdown]
# ## Statistical measure for numeric column

# %%
store.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.478567
# std      174.340972      57.251373
# min    -6599.978000       1.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %% [markdown]
# ## Statistical measure for object column

# %%
store.describe(include='O')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %% [markdown]
# ## How many null\Nan rows are present in each column

# %%
store.isna().sum()
# Out:
# Row ID                         0
# Order ID                       0
# Order Date                     0
# Ship Date                      0
# Ship Mode                      0
# Customer ID                    0
# Customer Name                  0
# Segment                        0
# Postal Code                41296
# City                           0
# State                          0
# Country                        0
# Region                         0
# Market                         0
# Product ID                     0
# Category                       0
# Sub-Category                   0
# Product Name                   0
# Sales                          0
# Quantity                       0
# Discount                       0
# Profit                         0
# Profit Category-Updated        0
# Profit Category                0
# Shipping Cost                  0
# Order Priority                 0
# dtype: int64

# %% [markdown]
# ## Handling Null values

# %% [markdown]
# delete column 'Postal Code' which has multiple null values, this column is not used for any statistical measure.

# %%
store.drop(['Postal Code'], axis=1,inplace=True)
store.head(5)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment           City  \
# 0  AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate     Wollongong
# 2     CR-127307      Craig Reiter     Consumer       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          Dakar
#
#              State        Country          Region        Market   Product ID  \
# 0         Oklahoma  United States      Central US          USCA  TEC-PH-5816
# ...

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Profit Category-Updated', 'Profit Category', 'Shipping Cost',
#        'Order Priority'],
#       dtype='object')

# %% [markdown]
# ## Create new column "year" and "month" from "Order Date"

# %%
import datetime as dt

# %%
store['Order_Month']=store['Order Date'].dt.month
store['Order_Year']=store['Order Date'].dt.year
store['Ship_Month']=store['Ship Date'].dt.month
store['Ship_Year']=store['Ship Date'].dt.year
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Profit Category-Updated', 'Profit Category', 'Shipping Cost',
#        'Order Priority', 'Order_Month', 'Order_Year', 'Ship_Month',
#        'Ship_Year'],
#       dtype='object')

# %% [markdown]
# ## Unique values in each column

# %%
store.Order_Year.nunique()
# Out:
# 4

# %%
store.Ship_Year.nunique()
# Out:
# 5

# %%
store.Order_Year.unique()
# Out:
# array([2014, 2012, 2013, 2015], dtype=int64)

# %%
store.Ship_Year.unique()
# Out:
# array([2014, 2012, 2013, 2015, 2016], dtype=int64)

# %%
store.rename({'Ship Mode':'Ship_Mode'}, axis=1, inplace=True)

# %%
store.Ship_Mode.nunique()
# Out:
# 4

# %%
store.Ship_Mode.unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'Standard Class'],
#       dtype=object)

# %%
store.Segment.nunique()
# Out:
# 3

# %%
store.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
store.Region.unique()
# Out:
# array(['Central US', 'Oceania', 'Western Europe', 'Western Africa',
#        'Western US', 'Southern Asia', 'Western Asia', 'South America',
#        'Eastern Asia', 'Southern Europe', 'Eastern Africa',
#        'Eastern Europe', 'Northern Europe', 'Central America',
#        'Eastern US', 'Caribbean', 'Central Africa', 'Southeastern Asia',
#        'Southern US', 'North Africa', 'Southern Africa', 'Canada',
#        'Central Asia'], dtype=object)

# %%
store.Market.unique()
# Out:
# array(['USCA', 'Asia Pacific', 'Europe', 'Africa', 'LATAM'], dtype=object)

# %%
store.Category.unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
store.rename({'Sub-Category':'Sub_Category'},axis=1,inplace=True)

# %%
store.Sub_Category.unique()
# Out:
# array(['Phones', 'Chairs', 'Copiers', 'Tables', 'Bookcases', 'Art',
#        'Appliances', 'Storage', 'Fasteners', 'Machines', 'Accessories',
#        'Furnishings', 'Binders', 'Labels', 'Paper', 'Supplies',
#        'Envelopes'], dtype=object)

# %% [markdown]
# ## Which category products are sold most of the time

# %%
store.Category.value_counts(ascending=False)
# Out:
# Office Supplies    31289
# Technology         10141
# Furniture           9860
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(6,6))
ax=sns.countplot(x='Category', data=store, order=store.Category.value_counts(ascending=False).index)
plt.xticks(rotation=45);

values = store.Category.value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

# %% [markdown]
# ## Which sub category products are sold most of the time

# %%
store.Sub_Category.value_counts(ascending=False)
# Out:
# Binders        6146
# Storage        5049
# Art            4864
# Paper          3492
# Chairs         3434
# Phones         3357
# Furnishings    3154
# Accessories    3075
# Labels         2601
# Fasteners      2601
# Bookcases      2411
# Supplies       2407
# Envelopes      2387
# Copiers        2223
# Appliances     1742
# Machines       1486
# Tables          861
# Name: Sub_Category, dtype: int64

# %%
plt.figure(figsize=(12,6))
ax=sns.countplot(x='Sub_Category', data=store, order=store.Sub_Category.value_counts(ascending=False).index)
plt.xticks(rotation=45);

values = store.Sub_Category.value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

# %% [markdown]
# ## Which top 10 products are sold most of the times

# %%
store['Product Name'].value_counts(ascending=False)[:10]
# Out:
# Staples                                  227
# Cardinal Index Tab, Clear                 92
# Eldon File Cart, Single Width             90
# Rogers File Cart, Single Width            84
# Ibico Index Tab, Clear                    83
# Sanford Pencil Sharpener, Water Color     80
# Smead File Cart, Single Width             77
# Acco Index Tab, Clear                     75
# Stanley Pencil Sharpener, Water Color     75
# Avery Index Tab, Clear                    74
# Name: Product Name, dtype: int64

# %% [markdown]
# ## Which shipping method is most prefered

# %%
store.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# dtype: int64

# %%
plt.figure(figsize=(6,6))
ax=sns.countplot(x='Ship_Mode', data=store, order=store.Ship_Mode.value_counts(ascending=False).index)
plt.xticks(rotation=45);

values = store.Ship_Mode.value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

# %% [markdown]
# ## which Category has highest sale

# %%
pd.pivot_table(store, values='Sales',index=['Category'], aggfunc=sum).sort_values(by='Sales', ascending=False).round(0)
# Out:
#                      Sales
# Category
# Technology       4744557.0
# Furniture        4110452.0
# Office Supplies  3787493.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', )
        
sns.barplot(x='Category', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Category').Sales.sum().sort_values(ascending=False).index);

index=store.groupby('Category').Sales.sum().sort_values(ascending=False).index
values=store.groupby('Category').Sales.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ## Which sub category has highest sales

# %%
pd.pivot_table(store, values='Sales',index=['Sub_Category'], aggfunc=sum).sort_values(by='Sales', ascending=False).round(0)
# Out:
#                   Sales
# Sub_Category
# Phones        1706824.0
# Copiers       1509436.0
# Chairs        1501682.0
# Bookcases     1466572.0
# Storage       1126813.0
# Appliances    1010536.0
# Machines       779060.0
# Tables         757042.0
# Accessories    749237.0
# Binders        461869.0
# Furnishings    385156.0
# Art            371613.0
# Supplies       242811.0
# Paper          241788.0
# Envelopes      169217.0
# Fasteners       89495.0
# Labels          73350.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(18,6))
sns.barplot(x='Sub_Category', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Sub_Category').Sales.sum().sort_values(ascending=False).index)
plt.xticks(rotation=45);

index=store.groupby('Sub_Category').Sales.sum().sort_values(ascending=False).index
values=store.groupby('Sub_Category').Sales.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ## Sales by sub category within the category

# %%
pd.pivot_table(store, values='Sales', index=['Category','Sub_Category'],aggfunc=sum).round(0)
# Out:
#                                   Sales
# Category        Sub_Category
# Furniture       Bookcases     1466572.0
#                 Chairs        1501682.0
#                 Furnishings    385156.0
#                 Tables         757042.0
# Office Supplies Appliances    1010536.0
#                 Art            371613.0
#                 Binders        461869.0
#                 Envelopes      169217.0
#                 Fasteners       89495.0
#                 Labels          73350.0
#                 Paper          241788.0
#                 Storage       1126813.0
#                 Supplies       242811.0
# Technology      Accessories    749237.0
#                 Copiers       1509436.0
#                 Machines       779060.0
#                 Phones        1706824.0

# %% [markdown]
# ## which market place have more sale

# %%
pd.pivot_table(store,values='Sales', index='Market', aggfunc=sum).sort_values(by='Sales', ascending=False).round()
# Out:
#                   Sales
# Market
# Asia Pacific  4042658.0
# Europe        3287336.0
# USCA          2364129.0
# LATAM         2164605.0
# Africa         783773.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')

plt.figure(figsize=(6,6))
sns.barplot(x='Market', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Market').Sales.sum().sort_values(ascending=False).index)
plt.xticks(rotation=45);

index=store.groupby('Market').Sales.sum().sort_values(ascending=False).index
values=store.groupby('Market').Sales.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ## which Top 10 Country has more sales

# %%
pd.pivot_table(store, values='Sales', index='Country', aggfunc=sum).sort_values(by='Sales', ascending=False)[:10].round()
# Out:
#                     Sales
# Country
# United States   2297201.0
# Australia        925236.0
# France           858931.0
# China            700562.0
# Germany          628136.0
# Mexico           621553.0
# India            589486.0
# United Kingdom   528576.0
# Indonesia        404887.0
# Brazil           359925.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(12,6))
sns.barplot(x='Country', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Country').Sales.sum().sort_values(ascending=False)[:10].index)
plt.xticks(rotation=45);

index=store.groupby('Country').Sales.sum().sort_values(ascending=False)[:10].index
values=store.groupby('Country').Sales.sum().sort_values(ascending=False)[:10].values.round(0)

value_label(index, values)

# %% [markdown]
# ## Bottom 10 lowest sell by country

# %%
pd.pivot_table(store, values='Sales', index='Country', aggfunc=sum).sort_values(by='Sales')[:10].round()
# Out:
#                    Sales
# Country
# The Gambia          20.0
# Suriname            24.0
# Belize              75.0
# Oman                77.0
# Equatorial Guinea  151.0
# Armenia            157.0
# Bhutan             164.0
# Eritrea            188.0
# Macedonia          210.0
# French Guiana      224.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(12,6))
sns.barplot(x='Country', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Country').Sales.sum().sort_values(ascending=True)[:10].index)
plt.xticks(rotation=45);

index=store.groupby('Country').Sales.sum().sort_values(ascending=True)[:10].index
values=store.groupby('Country').Sales.sum().sort_values(ascending=True)[:10].values.round(0)

value_label(index, values)

# %% [markdown]
# ## Sales by region

# %%
pd.pivot_table(store, values='Sales', index='Region',aggfunc=sum).sort_values(by='Sales', ascending=False).round()
# Out:
#                        Sales
# Region
# Western Europe     1731930.0
# Central America    1223101.0
# Oceania            1100185.0
# Southeastern Asia   884423.0
# Southern Asia       866573.0
# Eastern Asia        855059.0
# Western US          725458.0
# Eastern US          678781.0
# Northern Europe     636779.0
# South America       617224.0
# Southern Europe     608594.0
# Central US          501240.0
# Southern US         391722.0
# Caribbean           324281.0
# Western Asia        317107.0
# Eastern Europe      310033.0
# North Africa        233217.0
# Western Africa      173879.0
# Central Africa      143630.0
# Eastern Africa      127856.0
# Southern Africa     105192.0
# Canada               66928.0
# Central Asia         19311.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=8)

plt.figure(figsize=(18,6))
sns.barplot(x='Region', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Region').Sales.sum().sort_values(ascending=False).index)
plt.xticks(rotation=45);

index=store.groupby('Region').Sales.sum().sort_values(ascending=False).index
values=store.groupby('Region').Sales.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ## which ship mode has collected most shipping charges in total

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=sum).sort_values(by='Shipping Cost', ascending=False).round()
# Out:
#                 Shipping Cost
# Ship_Mode
# Standard Class       618350.0
# Second Class         315010.0
# First Class          308586.0
# Same Day             116141.0

# %%
sns.barplot(x='Ship_Mode', y='Shipping Cost', data=store, ci=None, estimator=sum);

# %% [markdown]
# ## maximum and minimum shipping cost

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=max)
# Out:
#                 Shipping Cost
# Ship_Mode
# First Class            915.49
# Same Day               933.57
# Second Class           923.63
# Standard Class         878.38

# %%
pd.pivot_table(store, values='Shipping Cost', index='Ship_Mode', aggfunc=min)
# Out:
#                 Shipping Cost
# Ship_Mode
# First Class             1.010
# Same Day                1.010
# Second Class            1.002
# Standard Class          1.003

# %% [markdown]
# ## which category products are ordered most of time

# %%
pd.pivot_table(store, values='Quantity', index='Category', aggfunc=sum)
# Out:
#                  Quantity
# Category
# Furniture           34892
# Office Supplies    108244
# Technology          35176

# %% [markdown]
# ## Within the category which sub category products are ordered most of the times

# %%
pd.pivot_table(store, values='Quantity', index=['Category','Sub_Category'], aggfunc=sum)
# Out:
#                               Quantity
# Category        Sub_Category
# Furniture       Bookcases         8310
#                 Chairs           12336
#                 Furnishings      11163
#                 Tables            3083
# Office Supplies Appliances        6026
#                 Art              16215
#                 Binders          21403
#                 Envelopes         8210
#                 Fasteners         9051
#                 Labels            9301
#                 Paper            12672
#                 Storage          16884
#                 Supplies          8482
# Technology      Accessories      10946
#                 Copiers           7454
#                 Machines          4906
#                 Phones           11870

# %% [markdown]
# ## on which year the sale is highest

# %%
pd.pivot_table(store, values='Sales', index='Order_Year', aggfunc=sum).sort_values(by='Sales', ascending=False).round()
# Out:
#                 Sales
# Order_Year
# 2015        4299866.0
# 2014        3405746.0
# 2013        2677439.0
# 2012        2259451.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(8,6))
sns.barplot(x='Order_Year', y='Sales', data=store, estimator=sum, ci=None,
            order=store.groupby('Order_Year').Sales.sum().sort_values(ascending=False).index)
plt.xticks(rotation=45);

index=store.groupby('Order_Year').Sales.sum().sort_values(ascending=False).index
values=store.groupby('Order_Year').Sales.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ## Year wise Sales of category

# %%
pd.pivot_table(store, values='Sales', index=['Order_Year','Category'], aggfunc=sum).round()
# Out:
#                                 Sales
# Order_Year Category
# 2012       Furniture         756084.0
#            Office Supplies   675715.0
#            Technology        827652.0
# 2013       Furniture         858822.0
#            Office Supplies   795175.0
#            Technology       1023442.0
# 2014       Furniture        1117629.0
#            Office Supplies  1010812.0
#            Technology       1277305.0
# 2015       Furniture        1377917.0
#            Office Supplies  1305790.0
#            Technology       1616159.0

# %%
sns.barplot(y='Sales', x='Category', hue='Order_Year', data=store, ci=None, estimator=sum);

# %% [markdown]
# '''From above we can conclude that the sale of every category is increasing year by year'''

# %% [markdown]
# ## Year wise sale by sub-category within category

# %%
pd.pivot_table(store, values='Sales', index=['Order_Year','Category','Sub_Category'], aggfunc=sum).round()
# Out:
#                                             Sales
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases     259396.0
#                            Chairs        285731.0
#                            Furnishings    63825.0
#                            Tables        147131.0
#            Office Supplies Appliances    173290.0
# ...                                           ...
# 2015       Office Supplies Supplies       86177.0
#            Technology      Accessories   253488.0
#                            Copiers       550385.0
#                            Machines      260279.0
#                            Phones        552006.0
#
# [68 rows x 1 columns]

# %%
plt.figure(figsize=(20,6))
sns.barplot(y='Sales', x='Sub_Category', hue='Order_Year', data=store, estimator=sum, ci=None)
plt.xticks(rotation=45);

# %% [markdown]
# '''from above we can say that the sale of every sub-category is going up year by year'''

# %% [markdown]
# ## year wise profit

# %%
pd.pivot_table(store, values='Profit', index='Order_Year', aggfunc=sum).sort_values(by='Profit', ascending=False).round()
# Out:
#               Profit
# Order_Year
# 2015        504166.0
# 2014        406935.0
# 2013        307415.0
# 2012        248941.0

# %% [markdown]
# ## Year wise profit of each category

# %%
pd.pivot_table(store, values='Profit', index=['Order_Year','Category'], aggfunc=sum).round()
# Out:
#                               Profit
# Order_Year Category
# 2012       Furniture         53655.0
#            Office Supplies   86039.0
#            Technology       109247.0
# 2013       Furniture         58116.0
#            Office Supplies  103322.0
#            Technology       145977.0
# 2014       Furniture         84047.0
#            Office Supplies  149261.0
#            Technology       173627.0
# 2015       Furniture         89265.0
#            Office Supplies  179973.0
#            Technology       234928.0

# %%
sns.barplot(y='Profit', x='Category', hue='Order_Year', data=store, estimator=sum, ci=None);

# %% [markdown]
# '''For all category the profit is increasing with year'''

# %% [markdown]
# ## Profit of sub-category within category by year

# %%
pd.pivot_table(store, values='Profit', index=['Order_Year','Category','Sub_Category'], aggfunc=sum).round()
# Out:
#                                            Profit
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases      27519.0
#                            Chairs         29943.0
#                            Furnishings     7268.0
#                            Tables        -11075.0
#            Office Supplies Appliances     22820.0
# ...                                           ...
# 2015       Office Supplies Supplies        7355.0
#            Technology      Accessories    41594.0
#                            Copiers       104049.0
#                            Machines       18628.0
#                            Phones         70658.0
#
# [68 rows x 1 columns]

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='Profit', x='Sub_Category', hue='Order_Year', data=store, estimator=sum, ci=None);

# %% [markdown]
# '''From above: almost every sub-categories profit increasing year by year'''
# '''Profit of tables is decreasing year by year'''

# %% [markdown]
# ## Region wise profit

# %%
pd.pivot_table(store, values='Profit', index='Region', aggfunc=sum).sort_values(by='Profit', ascending=False).round()
# Out:
#                      Profit
# Region
# Western Europe     218434.0
# Eastern Asia       167102.0
# Southern Asia      159336.0
# Central America    158982.0
# Oceania            120089.0
# Western US         108418.0
# Eastern US          91523.0
# Northern Europe     83924.0
# Eastern Europe      77085.0
# Southern Europe     70109.0
# North Africa        57836.0
# Southern US         46749.0
# Central US          39706.0
# Central Africa      35384.0
# Caribbean           34571.0
# South America       28091.0
# Southern Africa     24159.0
# Eastern Africa      21901.0
# Southeastern Asia   17852.0
# Canada              17817.0
# Central Asia        -7282.0
# Western Africa     -50408.0
# Western Asia       -53922.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(18,6))
sns.barplot(x='Region', y='Profit', data=store, estimator=sum, ci=None,
            order=store.groupby('Region').Profit.sum().sort_values(ascending=False).index)
plt.xticks(rotation=45);

index=store.groupby('Region').Profit.sum().sort_values(ascending=False).index
values=store.groupby('Region').Profit.sum().sort_values(ascending=False).values.round(0)

value_label(index, values)

# %% [markdown]
# ''' Central Asia, Western Africa and Western Asia facing loss and the loss is huge'''

# %% [markdown]
# ## Segment wise prifit

# %%
pd.pivot_table(store, values='Profit', index='Segment', aggfunc=sum).sort_values(by='Profit', ascending=False).round()
# Out:
#                Profit
# Segment
# Consumer     749240.0
# Corporate    441208.0
# Home Office  277009.0

# %% [markdown]
# ## Which market place have more profit

# %%
pd.pivot_table(store, values='Profit', index='Market', aggfunc=sum).sort_values(by='Profit', ascending=False).round()
# Out:
#                 Profit
# Market
# Europe        449552.0
# Asia Pacific  403176.0
# USCA          304214.0
# LATAM         221643.0
# Africa         88872.0

# %% [markdown]
# ## Which top 10 countries giving highest profit

# %%
pd.pivot_table(store, values='Profit', index='Country', aggfunc=sum).sort_values(by='Profit', ascending=False)[:10].round()
# Out:
#                   Profit
# Country
# United States   286397.0
# China           150683.0
# India           129051.0
# United Kingdom  111900.0
# France          109029.0
# Germany         107190.0
# Australia       103907.0
# Mexico          102454.0
# Spain            54390.0
# El Salvador      42023.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(12,6))
sns.barplot(x='Country', y='Profit', data=store, estimator=sum, ci=None,
            order=store.groupby('Country').Profit.sum().sort_values(ascending=False)[:10].index)
plt.xticks(rotation=45);

index=store.groupby('Country').Profit.sum().sort_values(ascending=False)[:10].index
values=store.groupby('Country').Profit.sum().sort_values(ascending=False)[:10].values.round(0)

value_label(index, values)

# %% [markdown]
# ## which Bottom 10 countries are have negative profit

# %%
pd.pivot_table(store, values='Profit', index='Country', aggfunc=sum).sort_values(by='Profit', ascending=True)[:10].round()
# Out:
#               Profit
# Country
# Turkey      -98447.0
# Nigeria     -80751.0
# Netherlands -41070.0
# Honduras    -29482.0
# Pakistan    -22447.0
# Argentina   -18694.0
# Panama      -17723.0
# Sweden      -17519.0
# Philippines -16128.0
# South Korea -12793.0

# %%
def value_label(x_list, y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center', fontsize=12)

plt.figure(figsize=(12,6))
sns.barplot(x='Country', y='Profit', data=store, estimator=sum, ci=None,
            order=store.groupby('Country').Profit.sum().sort_values(ascending=True)[:10].index)
plt.xticks(rotation=45);

index=store.groupby('Country').Profit.sum().sort_values(ascending=True)[:10].index
values=store.groupby('Country').Profit.sum().sort_values(ascending=True)[:10].values.round(0)

value_label(index, values)

# %% [markdown]
# ## how many phones sold, profit and sales?

# %%
store_phones=store[store['Sub_Category']=='Phones']

# %%
store_phones.head(5)
# Out:
#     Row ID                  Order ID Order Date  Ship Date     Ship_Mode  \
# 0    40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 2    25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3    13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 5    22732    IN-2014-JM156557-41818 2014-06-28 2014-07-01  Second Class
# 12   45794   SA-2012-MM7260110-41269 2012-12-26 2012-12-28  Second Class
#
#      Customer ID     Customer Name      Segment           City  \
# 0   AB-100151402     Aaron Bergman     Consumer  Oklahoma City
# 2      CR-127307      Craig Reiter     Consumer       Brisbane
# 3     KM-1637548  Katherine Murray  Home Office         Berlin
# 5      JM-156557       Jim Mitchum    Corporate         Sydney
# 12    MM-7260110   Magdelene Morse     Consumer          Jizan
#
#               State        Country          Region        Market   Product ID  \
# ...

# %%
store_phones.value_counts('Sub_Category')
# Out:
# Sub_Category
# Phones    3357
# dtype: int64

# %%
pd.pivot_table(store_phones, values=['Sales','Profit','Quantity'], index=['Sub_Category','Order_Year'], aggfunc=sum).round()
# Out:
#                           Profit  Quantity     Sales
# Sub_Category Order_Year
# Phones       2012        53927.0      2244  337282.0
#              2013        45223.0      2545  364016.0
#              2014        46909.0      3145  453519.0
#              2015        70658.0      3936  552006.0

# %% [markdown]
# ## How many  tables sold, their sales and profit

# %%
store_tables=store[store['Sub_Category']=='Tables']

# %%
store_tables.head(5)
# Out:
#     Row ID                  Order ID Order Date  Ship Date       Ship_Mode  \
# 7    31192   IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# 11   28879    ID-2013-AJ107801-41383 2013-04-19 2013-04-22     First Class
# 20   46630    PL-2013-AB600103-41494 2013-08-08 2013-08-10     First Class
# 25    3484   MX-2015-VD2167039-42252 2015-09-05 2015-09-08     First Class
# 26   30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
#
#     Customer ID      Customer Name    Segment       City         State  \
# 7    MB-1808592         Mick Brown   Consumer   Hamilton       Waikato
# 11    AJ-107801     Anthony Jacobs  Corporate      Kabul         Kabul
# 20    AB-600103          Ann Blume  Corporate      Bytom       Silesia
# 25   VD-2167039  Valerie Dominguez   Consumer  Soyapango  San Salvador
# 26  PB-19210127     Phillip Breyer  Corporate     Taipei   Taipei City
#
#         Country           Region        Market   Product ID   Category  \
# ...

# %%
store_tables.value_counts('Sub_Category')
# Out:
# Sub_Category
# Tables    861
# dtype: int64

# %%
pd.pivot_table(store_tables, values=['Quantity','Sales','Profit'], index=['Sub_Category','Order_Year'], aggfunc=sum).round()
# Out:
#                           Profit  Quantity     Sales
# Sub_Category Order_Year
# Tables       2012       -11075.0       610  147131.0
#              2013        -8422.0       627  164086.0
#              2014       -14040.0       819  202364.0
#              2015       -30546.0      1027  243460.0

# %% [markdown]
# such manner we can find sales of any product

# %% [markdown]
# ## Analysis on INDIA

# %%
sales_india=store[(store['Country']=='India')]

# %%
sales_india.head(5)
# Out:
#     Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 29   22999  IN-2013-BP1123058-41329 2013-02-24 2013-02-24        Same Day
# 41   29272  IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 42   25795  IN-2015-VG2180558-42273 2015-09-26 2015-09-28    Second Class
# 48   28701  IN-2015-SW2027558-42125 2015-05-01 2015-05-01        Same Day
# 55   29047  IN-2013-SG2047058-41424 2013-05-30 2013-05-31     First Class
#
#    Customer ID       Customer Name      Segment                City  \
# 29  BP-1123058  Benjamin Patterson     Consumer               Surat
# 41  BF-1100558         Barry Franz  Home Office           Gorakhpur
# 42  VG-2180558         Vivek Grady    Corporate  Thiruvananthapuram
# 48  SW-2027558    Scott Williamson     Consumer          Jamshedpur
# 55  SG-2047058        Sheri Gordon     Consumer              Bhopal
#
#              State Country         Region        Market   Product ID  \
# ...

# %%
pd.pivot_table(sales_india, values='Sales', index='Country', aggfunc=sum).round()
# Out:
#             Sales
# Country
# India    589486.0

# %% [markdown]
# ## which sipping method is most preffered in india

# %%
sales_india.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    972
# Second Class      330
# First Class       187
# Same Day           65
# dtype: int64

# %% [markdown]
# ## Total shipping charges collected in india

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=sum)
# Out:
#          Shipping Cost
# Country
# India         61840.43

# %% [markdown]
# ## maximum and minimum shipping cost

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=max)
# Out:
#          Shipping Cost
# Country
# India           704.08

# %%
pd.pivot_table(sales_india, values='Shipping Cost', index='Country', aggfunc=min)
# Out:
#          Shipping Cost
# Country
# India             1.01

# %% [markdown]
# ## profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index='Country', aggfunc=sum).round()
# Out:
#            Profit
# Country
# India    129051.0

# %% [markdown]
# ## Which segment is preffered in india

# %%
sales_india.value_counts('Segment')
# Out:
# Segment
# Consumer       816
# Corporate      430
# Home Office    308
# dtype: int64

# %% [markdown]
# ## Which Category of product is most preffered

# %%
sales_india.value_counts('Category')
# Out:
# Category
# Office Supplies    840
# Furniture          360
# Technology         354
# dtype: int64

# %% [markdown]
# ## Which sub-category product is most preffered in india

# %%
sales_india.value_counts('Sub_Category')
# Out:
# Sub_Category
# Binders        146
# Chairs         139
# Phones         119
# Storage        107
# Paper          105
# Accessories    102
# Furnishings     99
# Bookcases       98
# Labels          94
# Fasteners       93
# Envelopes       91
# Supplies        86
# Copiers         84
# Art             76
# Machines        49
# Appliances      42
# Tables          24
# dtype: int64

# %% [markdown]
# ## Year wise sales in india

# %%
pd.pivot_table(sales_india, values='Sales', index='Order_Year', aggfunc=sum).round()
# Out:
#                Sales
# Order_Year
# 2012         91396.0
# 2013        141329.0
# 2014        151729.0
# 2015        205032.0

# %% [markdown]
# ## Year and category wise sale in india

# %%
pd.pivot_table(sales_india, values='Sales', index=['Order_Year','Category'], aggfunc=sum).round()
# Out:
#                               Sales
# Order_Year Category
# 2012       Furniture        33367.0
#            Office Supplies  17557.0
#            Technology       40472.0
# 2013       Furniture        48680.0
#            Office Supplies  32762.0
#            Technology       59887.0
# 2014       Furniture        53025.0
#            Office Supplies  28441.0
#            Technology       70263.0
# 2015       Furniture        80984.0
#            Office Supplies  52410.0
#            Technology       71638.0

# %% [markdown]
# ## Year wise profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year'], aggfunc=sum).round()
# Out:
#              Profit
# Order_Year
# 2012        19929.0
# 2013        27418.0
# 2014        32897.0
# 2015        48808.0

# %% [markdown]
# ## Year and category wise profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year','Category'], aggfunc=sum).round()
# Out:
#                              Profit
# Order_Year Category
# 2012       Furniture         6494.0
#            Office Supplies   4445.0
#            Technology        8989.0
# 2013       Furniture         7951.0
#            Office Supplies   6894.0
#            Technology       12572.0
# 2014       Furniture         9348.0
#            Office Supplies   6821.0
#            Technology       16727.0
# 2015       Furniture        18642.0
#            Office Supplies  12362.0
#            Technology       17804.0

# %% [markdown]
# ## Year and sub-category wise profit in india

# %%
pd.pivot_table(sales_india, values='Profit', index=['Order_Year','Category','Sub_Category'], aggfunc=sum)
# Out:
#                                            Profit
# Order_Year Category        Sub_Category
# 2012       Furniture       Bookcases     3496.350
#                            Chairs        1613.625
#                            Furnishings   1045.650
#                            Tables         338.460
#            Office Supplies Appliances    1758.360
# ...                                           ...
# 2015       Office Supplies Supplies       960.420
#            Technology      Accessories   2147.310
#                            Copiers       6212.190
#                            Machines      2444.460
#                            Phones        7000.140
#
# [68 rows x 1 columns]

# %% [markdown]
# ## Total states of india under global superstore market

# %%
sales_india.State.unique()
# Out:
# array(['Gujarat', 'Haryana', 'Kerala', 'Jharkhand', 'Madhya Pradesh',
#        'Delhi', 'Uttarakhand', 'West Bengal', 'Bihar', 'Uttar Pradesh',
#        'Chhattisgarh', 'Tamil Nadu', 'Maharashtra', 'Karnataka',
#        'Rajasthan', 'Manipur', 'Andhra Pradesh', 'Jammu and Kashmir',
#        'Telangana', 'Punjab', 'Odisha', 'Puducherry', 'Assam',
#        'Chandigarh', 'Tripura'], dtype=object)

# %% [markdown]
# ## State wise profit and sales india

# %%
def value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.annotate(y_list[i],(i,y_list[i]), ha='center')
        
plt.figure(figsize=(20,6))
sns.barplot(x='State', y='Sales', data=sales_india, estimator=sum, ci=None,
           order=sales_india.groupby('State').Sales.sum().sort_values(ascending=True).index)
plt.xticks(rotation=90);

index=sales_india.groupby('State').Sales.sum().sort_values(ascending=True).index
values=sales_india.groupby('State').Sales.sum().sort_values(ascending=True).values.round()

value_label(index, values)

# %% [markdown]
# ## Finding sales in karnataka

# %%
sales_karnataka=sales_india[(sales_india['State']=='Karnataka')]

# %%
sales_karnataka.head(5)
# Out:
#       Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 408    27724  IN-2015-CY1274558-42300 2015-10-23 2015-10-25     First Class
# 782    27579  IN-2015-JW1522058-42101 2015-04-07 2015-04-12  Standard Class
# 1957   22906  IN-2014-RA1928558-41863 2014-08-12 2014-08-16  Standard Class
# 2364   28779  IN-2014-BO1135058-41783 2014-05-24 2014-05-30  Standard Class
# 2584   22907  IN-2014-RA1928558-41863 2014-08-12 2014-08-16  Standard Class
#
#      Customer ID  Customer Name    Segment       City      State Country  \
# 408   CY-1274558   Craig Yedwab  Corporate  Bangalore  Karnataka   India
# 782   JW-1522058      Jane Waco  Corporate  Mangalore  Karnataka   India
# 1957  RA-1928558   Ralph Arnett   Consumer  Mangalore  Karnataka   India
# 2364  BO-1135058  Bill Overfelt  Corporate  Bangalore  Karnataka   India
# 2584  RA-1928558   Ralph Arnett   Consumer  Mangalore  Karnataka   India
#
# ...

# %%
pd.pivot_table(sales_karnataka, values='Sales', index='State', aggfunc=sum)
# Out:
#              Sales
# State
# Karnataka  31802.4

# %%
pd.pivot_table(sales_karnataka, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#                Sales
# Order_Year
# 2012         2430.72
# 2013         4622.28
# 2014        11077.68
# 2015        13671.72

# %%
pd.pivot_table(sales_karnataka, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                               Sales
# Order_Year Category
# 2012       Furniture         743.25
#            Office Supplies  1304.91
#            Technology        382.56
# 2013       Furniture        2103.81
#            Office Supplies  1139.31
#            Technology       1379.16
# 2014       Furniture        4787.52
#            Office Supplies  1918.11
#            Technology       4372.05
# 2015       Furniture        3058.62
#            Office Supplies  3414.18
#            Technology       7198.92

# %% [markdown]
# ## Profit in karnataka

# %%
pd.pivot_table(sales_karnataka, values='Profit', index='Country', aggfunc=sum)
# Out:
#           Profit
# Country
# India    9290.34

# %%
pd.pivot_table(sales_karnataka, values='Profit', index='Order_Year', aggfunc=sum)
# Out:
#              Profit
# Order_Year
# 2012         672.84
# 2013        1051.44
# 2014        2855.73
# 2015        4710.33

# %%
pd.pivot_table(sales_karnataka, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                              Profit
# Order_Year Category
# 2012       Furniture         133.65
#            Office Supplies   470.55
#            Technology         68.64
# 2013       Furniture         263.46
#            Office Supplies   396.90
#            Technology        391.08
# 2014       Furniture        1406.25
#            Office Supplies   449.07
#            Technology       1000.41
# 2015       Furniture         798.36
#            Office Supplies   825.60
#            Technology       3086.37

# %% [markdown]
# ## Cities in karnataka

# %%
sales_karnataka.City.unique()
# Out:
# array(['Bangalore', 'Mangalore', 'Tumkur', 'Belgaum', 'Hubli', 'Bijapur',
#        'Bellary', 'Gulbarga', 'Mysore', 'Shimoga'], dtype=object)

# %% [markdown]
# ## Finding sales in my city 'BELGAUM'

# %%
sales_belgaum=sales_india[sales_india['City']=='Belgaum']

# %%
sales_belgaum.head(5)
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship_Mode  \
# 4564    23651  IN-2013-MG1769558-41620 2013-12-12 2013-12-18  Standard Class
# 5132    28511  IN-2012-AH1046558-41059 2012-05-30 2012-05-30        Same Day
# 8148    21018  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
# 8944    25405  IN-2013-KD1634558-41452 2013-06-27 2013-07-02  Standard Class
# 12115   21017  IN-2014-KT1646558-41902 2014-09-20 2014-09-22     First Class
#
#       Customer ID     Customer Name   Segment     City      State Country  \
# 4564   MG-1769558     Maureen Gnade  Consumer  Belgaum  Karnataka   India
# 5132   AH-1046558          Amy Hunt  Consumer  Belgaum  Karnataka   India
# 8148   KT-1646558     Kean Takahito  Consumer  Belgaum  Karnataka   India
# 8944   KD-1634558  Katherine Ducich  Consumer  Belgaum  Karnataka   India
# 12115  KT-1646558     Kean Takahito  Consumer  Belgaum  Karnataka   India
#
# ...

# %%
sales_belgaum.value_counts('Ship_Mode')
# Out:
# Ship_Mode
# Standard Class    5
# First Class       3
# Same Day          2
# dtype: int64

# %%
pd.pivot_table(sales_belgaum, values='Sales', index='City', aggfunc=sum)
# Out:
#            Sales
# City
# Belgaum  3478.26

# %%
pd.pivot_table(sales_belgaum, values='Sales', index='Order_Year', aggfunc=sum)
# Out:
#               Sales
# Order_Year
# 2012         521.25
# 2013        2295.36
# 2014         661.65

# %%
pd.pivot_table(sales_belgaum, values='Sales', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                               Sales
# Order_Year Category
# 2012       Office Supplies   138.69
#            Technology        382.56
# 2013       Furniture        1601.28
#            Office Supplies   694.08
# 2014       Furniture         661.65

# %% [markdown]
# ## profit in belgaum

# %%
pd.pivot_table(sales_belgaum, values='Profit', index='City', aggfunc=sum)
# Out:
#          Profit
# City
# Belgaum  755.49

# %%
pd.pivot_table(sales_belgaum, values='Profit', index='Order_Year', aggfunc=sum)
# Out:
#             Profit
# Order_Year
# 2012        119.94
# 2013        425.25
# 2014        210.30

# %%
pd.pivot_table(sales_belgaum, values='Profit', index=['Order_Year','Category'], aggfunc=sum)
# Out:
#                             Profit
# Order_Year Category
# 2012       Office Supplies   51.30
#            Technology        68.64
# 2013       Furniture        202.68
#            Office Supplies  222.57
# 2014       Furniture        210.30

# %% [markdown]
# ## total shipping cost collected in belgaum city

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=sum)
# Out:
#          Shipping Cost
# City
# Belgaum         300.62

# %% [markdown]
# ## minimum and maximum shipping cost

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=min)
# Out:
#          Shipping Cost
# City
# Belgaum           4.72

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='City', aggfunc=max)
# Out:
#          Shipping Cost
# City
# Belgaum          72.14

# %% [markdown]
# ## which Category has maximum shipping cost

# %%
pd.pivot_table(sales_belgaum, values='Shipping Cost', index='Category', aggfunc=max)
# Out:
#                  Shipping Cost
# Category
# Furniture                72.14
# Office Supplies          11.19
# Technology               65.04

# %% [markdown]
# ## Quantity of product ordered

# %%
pd.pivot_table(sales_belgaum, values='Quantity', index='Product Name', aggfunc=sum)
# Out:
#                                        Quantity
# Product Name
# BIC Highlighters, Water Color                 2
# Cameo Interoffice Envelope, Recycled          3
# Fellowes File Cart, Single Width              3
# Hon Chairmat, Black                           3
# Ikea 3-Shelf Cabinet, Metal                   3
# Logitech Numeric Keypad, Programmable         8
# Rubbermaid Clock, Black                       5
# SanDisk Note Cards, 8.5 x 11                  8
# Sauder Floating Shelf Set, Pine               6
# Tenex Clock, Duo Pack                         5

# %%
pd.pivot_table(sales_belgaum, values=['Profit','Sales','Quantity'], index='Product Name', aggfunc=sum)
# Out:
#                                        Profit  Quantity    Sales
# Product Name
# BIC Highlighters, Water Color            0.00         2    44.22
# Cameo Interoffice Envelope, Recycled    51.30         3   138.69
# Fellowes File Cart, Single Width       206.01         3   412.02
# Hon Chairmat, Black                     27.00         3   159.30
# Ikea 3-Shelf Cabinet, Metal             85.14         3   425.70
# Logitech Numeric Keypad, Programmable   68.64         8   382.56
# Rubbermaid Clock, Black                 85.20         5   250.80
# SanDisk Note Cards, 8.5 x 11            16.56         8   237.84
# Sauder Floating Shelf Set, Pine        117.54         6  1175.58
# Tenex Clock, Duo Pack                   98.10         5   251.55

# %%
pd.pivot_table(sales_belgaum, values=['Quantity','Sales','Profit','Discount'], index='Product Name', aggfunc=sum)
# Out:
#                                        Discount  Profit  Quantity    Sales
# Product Name
# BIC Highlighters, Water Color               0.0    0.00         2    44.22
# Cameo Interoffice Envelope, Recycled        0.0   51.30         3   138.69
# Fellowes File Cart, Single Width            0.0  206.01         3   412.02
# Hon Chairmat, Black                         0.0   27.00         3   159.30
# Ikea 3-Shelf Cabinet, Metal                 0.0   85.14         3   425.70
# Logitech Numeric Keypad, Programmable       0.0   68.64         8   382.56
# Rubbermaid Clock, Black                     0.0   85.20         5   250.80
# SanDisk Note Cards, 8.5 x 11                0.0   16.56         8   237.84
# Sauder Floating Shelf Set, Pine             0.0  117.54         6  1175.58
# Tenex Clock, Duo Pack                       0.0   98.10         5   251.55

# %% [markdown]
# ## Create sample online bill sheet

# %%
pd.pivot_table(sales_belgaum, values=['Quantity','Sales','Shipping Cost'], index=['Customer Name','Product Name','Ship_Mode'], aggfunc=sum)
# Out:
#                                                                        Quantity  \
# Customer Name    Product Name                          Ship_Mode
# Amy Hunt         Cameo Interoffice Envelope, Recycled  Same Day               3
#                  Logitech Numeric Keypad, Programmable Same Day               8
# Katherine Ducich BIC Highlighters, Water Color         Standard Class         2
#                  Ikea 3-Shelf Cabinet, Metal           Standard Class         3
# Kean Takahito    Hon Chairmat, Black                   First Class            3
#                  Rubbermaid Clock, Black               First Class            5
#                  Tenex Clock, Duo Pack                 First Class            5
# Maureen Gnade    Fellowes File Cart, Single Width      Standard Class         3
#                  SanDisk Note Cards, 8.5 x 11          Standard Class         8
#                  Sauder Floating Shelf Set, Pine       Standard Class         6
#
# ...
